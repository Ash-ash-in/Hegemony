# %%
import os
root = os.getcwd()
print(os.path.join(root, "game", "data", "companies.csv"))
# Out:
# c:\Users\ashhp\Projects\Hegemony\game\data\companies.csv

# %%
import pandas as pd
import os
root = os.getcwd()
comp_df = pd.read_csv(os.path.join(root, "game", "data", "companies.csv"))
comp_df.tail()
# Out:
#             Owner                    Name  Cost     Industry  Base Production  \
# 54   Middle Class  Regional Radio Station    20        Media                2
# 55   Middle Class               PR Agency    20        Media                3
# 56   Middle Class         Local Newspaper    14        Media                2
# 57  Working Class        Cooperative Farm     0  Agriculture                2
# 58  Working Class        Cooperative Farm     0  Agriculture                2
#
#      L1    L2    L3 Class1 Skill1 Class2 Skill2 Class3 Skill3  Upgrade Value
# 54  9.0  12.0  15.0     MC  Media     WC  Media    NaN    NaN            2.0
# 55  NaN   NaN   NaN     MC  Media     MC    Any    NaN    NaN            NaN
# 56  6.0   8.0  10.0     MC  Media     WC    Any    NaN    NaN            1.0
# 57  NaN   NaN   NaN     WC    Any     WC    Any     WC    Any            NaN
# 58  NaN   NaN   NaN     WC    Any     WC    Any     WC    Any            NaN

# %%
from game.data.common import Company, Worker
working_class_company_pool = []
middle_class_company_pool = []
capitalists_company_pool = []
state_company_pool = []
for index, row in comp_df.iterrows():
    comp = Company()

# %%
import game.data.common as common
print(common.__file__)          # confirm it's the right file
print(dir(common))              # see everything actually on the module
companies = common.build_company_pools()
print(companies)
# Out:
# c:\Users\ashhp\Projects\Hegemony\game\data\common.py
# ['Card', 'Company', 'Event', 'GameState', 'PlayerReference', 'Worker', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'dataclass', 'faction_instantiate_order', 'faction_play_order', 'field', 'logger', 'logging', 'phases']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 4
#       1 import game.data.common as common
#       2 print(common.__file__)          # confirm it's the right file
#       3 print(dir(common))              # see everything actually on the module
# ----> 4 companies = common.build_company_pools()
#       5 print(companies)
#
# AttributeError: module 'game.data.common' has no attribute 'build_company_pools'
