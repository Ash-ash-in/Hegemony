# %%
import os
root = os.getcwd()
print(os.path.join(root, "game", "data", "companies.csv"))
# Out:
# c:\Users\ashhp\Projects\Hegemony\game\data\companies.csv

# %%
import pandas as pd
import os
root = os.getcwd()
comp_df = pd.read_csv(os.path.join(root, "game", "data", "companies.csv"))
comp_df.tail()
# Out:
#             Owner                    Name  Cost     Industry  Base Production  \
# 54   Middle Class  Regional Radio Station    20        Media                2
# 55   Middle Class               PR Agency    20        Media                3
# 56   Middle Class         Local Newspaper    14        Media                2
# 57  Working Class        Cooperative Farm     0  Agriculture                2
# 58  Working Class        Cooperative Farm     0  Agriculture                2
#
#      L1    L2    L3 Class1 Skill1 Class2 Skill2 Class3 Skill3  Upgrade Value
# 54  9.0  12.0  15.0     MC  Media     WC  Media    NaN    NaN            2.0
# 55  NaN   NaN   NaN     MC  Media     MC    Any    NaN    NaN            NaN
# 56  6.0   8.0  10.0     MC  Media     WC    Any    NaN    NaN            1.0
# 57  NaN   NaN   NaN     WC    Any     WC    Any     WC    Any            NaN
# 58  NaN   NaN   NaN     WC    Any     WC    Any     WC    Any            NaN

# %%
from game.data import common
companies = common.build_company_pools()
print(companies)
# Out:
# common.py fully loaded
# {'working_class': [Company(name='Cooperative Farm', faction='Working Class', industry='Agriculture', cost=0, production=2, production_bonus=0, production_bonus_active=False, wages=None, worker_slots=[Worker(faction='WC', skill='Any', alive=True, employed=True), Worker(faction='WC', skill='Any', alive=True, employed=True), Worker(faction='WC', skill='Any', alive=True, employed=True)], workers=[], id=57), Company(name='Cooperative Farm', faction='Working Class', industry='Agriculture', cost=0, production=2, production_bonus=0, production_bonus_active=False, wages=None, worker_slots=[Worker(faction='WC', skill='Any', alive=True, employed=True), Worker(faction='WC', skill='Any', alive=True, employed=True), Worker(faction='WC', skill='Any', alive=True, employed=True)], workers=[], id=58)], 'middle_class': [Company(name='Private School', faction='Middle Class', industry='Education', cost=20, production=2, production_bonus=4.0, production_bonus_active=False, wages={'L1': 9.0, 'L2': 12.0, 'L3': 15.0}, worker_slots=[Worker(faction='MC', skill='Education', alive=True, employed=True), Worker(faction='WC', skill='Education', alive=True, employed=True)], workers=[], id=40), Company(name='Training Centre', faction='Middle Class', industry='Education', cost=16, production=4, production_bonus=0, production_bonus_active=False, wages=None, worker_slots=[Worker(faction='MC', skill='Education', alive=True, employed=True), Worker(faction='MC', skill='Any', alive=True, employed=True)], workers=[], id=41), Company(name='Tutoring Company', faction='Middle Class', industry='Education', cost=12, production=2, production_bonus=2.0, production_bonus_active=False, wages={'L1': 6.0, 'L2': 8.0, 'L3': 10.0}, worker_slots=[Worker(faction='MC', skill='Education', alive=True, employed=True), Worker(faction='WC', skill='Any', alive=True, employed=True)], workers=[], id=42), Company(name="Doctor's Office", faction='Middle Class', industry='Healthcare', cost=12, production=2, production_bonus=2.0, production_bonus_active=False, wages={'L1': 6.0, 'L2': 8.0, 'L3': 10.0}, worker_slots=[Worker(faction='MC', skill='Healthcarecare', alive=True, employed=True), Worker(faction='WC', skill='Any', alive=True, employed=True)], workers=[], id=43), Company(name="Doctor's Office", faction='Middle Class', industry='Healthcare', cost=12, production=2, production_bonus=2.0, production_bonus_active=False, wages={'L1': 6.0, 'L2': 8.0, 'L3': 10.0}, worker_slots=[Worker(faction='MC', skill='Healthcarecare', alive=True, employed=True), Worker(faction='WC', skill='Any', alive=True, employed=True)], workers=[], id=44), Company(name='Pharmacy', faction='Middle Class', industry='Healthcare', cost=16, production=4, production_bonus=0, production_bonus_active=False, wages=None, worker_slots=[Worker(faction='MC', skill='Healthcarecare', alive=True, employed=True), Worker(faction='MC', skill='Any', alive=True, employed=True)], workers=[], id=45), Company(name='Medical Laboratory', faction='Middle Class', industry='Healthcare', cost=20, production=2, production_bonus=4.0, production_bonus_active=False, wages={'L1': 9.0, 'L2': 12.0, 'L3': 15.0}, worker_slots=[Worker(faction='MC', skill='Healthcarecare', alive=True, employed=True), Worker(faction='WC', skill='Healthcarecare', alive=True, employed=True)], workers=[], id=46), Company(name='Organic Farm', faction='Middle Class', industry='Agriculture', cost=20, production=2, production_bonus=2.0, production_bonus_active=False, wages={'L1': 9.0, 'L2': 12.0, 'L3': 15.0}, worker_slots=[Worker(faction='MC', skill='Agriculture', alive=True, employed=True), Worker(faction='WC', skill='Agriculture', alive=True, employed=True)], workers=[], id=47), Company(name='Fast Agriculture Restaurant', faction='Middle Class', industry='Agriculture', cost=20, production=3, production_bonus=0, production_bonus_active=False, wages=None, worker_slots=[Worker(faction='MC', skill='Agriculture', alive=True, employed=True), Worker(faction='MC', skill='Any', alive=True, employ ...

# %%
dict1 = {'a': 1, 'b': 2}
dict2 = {'c':3}
dict1 = {**dict1, **dict2}
print(dict1)
# Out:
# {'a': 1, 'b': 2, 'c': 3}
